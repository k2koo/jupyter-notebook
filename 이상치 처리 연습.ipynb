# %%
import pandas as pd
data=pd.read_csv('Ex_CEOSalary.csv', encoding='utf-8')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209 entries, 0 to 208
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   salary    209 non-null    int64
#  1   sales     209 non-null    float64
#  2   roe       209 non-null    float64
#  3   industry  209 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 6.7 KB

# %%
data.boxplot(column='salary', return_type='both')
# Out:
# BP(ax=<AxesSubplot:>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x0000024F241B2EC0>, <matplotlib.lines.Line2D object at 0x0000024F241B3190>], 'caps': [<matplotlib.lines.Line2D object at 0x0000024F241B3460>, <matplotlib.lines.Line2D object at 0x0000024F241B3730>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000024F241B2BF0>], 'medians': [<matplotlib.lines.Line2D object at 0x0000024F241B3A00>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000024F241B3CD0>], 'means': []})

# %%
data.boxplot(column='sales', return_type='both')
# Out:
# BP(ax=<AxesSubplot:>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x0000024F24454EB0>, <matplotlib.lines.Line2D object at 0x0000024F24455180>], 'caps': [<matplotlib.lines.Line2D object at 0x0000024F24455450>, <matplotlib.lines.Line2D object at 0x0000024F24455720>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000024F24454C40>], 'medians': [<matplotlib.lines.Line2D object at 0x0000024F244559F0>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000024F24455CC0>], 'means': []})

# %%
data.boxplot(column='roe', return_type='both')
# Out:
# BP(ax=<AxesSubplot:>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x0000024F241DC850>, <matplotlib.lines.Line2D object at 0x0000024F241DCB20>], 'caps': [<matplotlib.lines.Line2D object at 0x0000024F241DCDF0>, <matplotlib.lines.Line2D object at 0x0000024F241DD0C0>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000024F241DC5E0>], 'medians': [<matplotlib.lines.Line2D object at 0x0000024F241DD390>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000024F241DD660>], 'means': []})

# %%
Q1_salary = data['salary'].quantile(q=0.25)
Q3_salary = data['salary'].quantile(q=0.75)
IQR_salary = Q3_salary-Q1_salary
IQR_salary
# Out:
# 671.0

# %%
data_IQR=data[(data['salary']<Q3_salary+IQR_salary*1.5)&(data['salary']>Q1_salary-IQR_salary*1.5)]
data_IQR['salary'].hist()
# Out:
# <AxesSubplot:>

# %%
data_IQR.boxplot(column='salary', return_type='both')
# Out:
# BP(ax=<AxesSubplot:>, lines={'whiskers': [<matplotlib.lines.Line2D object at 0x0000024F245CB310>, <matplotlib.lines.Line2D object at 0x0000024F245CB5E0>], 'caps': [<matplotlib.lines.Line2D object at 0x0000024F245CB8B0>, <matplotlib.lines.Line2D object at 0x0000024F245CBB80>], 'boxes': [<matplotlib.lines.Line2D object at 0x0000024F245CB040>], 'medians': [<matplotlib.lines.Line2D object at 0x0000024F245CBE50>], 'fliers': [<matplotlib.lines.Line2D object at 0x0000024F24600160>], 'means': []})

# %%
data_IQR.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'sales'}>],
#        [<AxesSubplot:title={'center':'roe'}>,
#         <AxesSubplot:title={'center':'industry'}>]], dtype=object)

# %%
data_IQR.corr()
# Out:
#             salary     sales       roe  industry
# salary    1.000000  0.335446  0.289704 -0.202648
# sales     0.335446  1.000000 -0.065034 -0.069790
# roe       0.289704 -0.065034  1.000000 -0.024423
# industry -0.202648 -0.069790 -0.024423  1.000000

# %%
import matplotlib.pyplot as plt
plt.scatter(data_IQR['sales'], data_IQR['salary'], alpha=0.5)
plt.show()

# %%
plt.scatter(data_IQR['roe'], data_IQR['salary'], alpha=0.5)
plt.show()

# %%
Q1_sales = data['sales'].quantile(q=0.25)
Q3_sales = data['sales'].quantile(q=0.75)
IQR_sales = Q3_sales-Q1_sales
IQR_sales
# Out:
# 4966.6999511718695

# %%
data_IQR=data[(data['sales']<Q3_sales+IQR_sales*1.5)& (data['sales']>Q1_sales-IQR_sales*1.5) &
             (data['salary']<Q3_salary+IQR_salary*1.5)&
             (data['salary']>Q1_salary-IQR_salary*1.5)]
data_IQR['sales'].hist()
data_IQR.hist(bins=50, figsize=(20,15))
# Out:
# array([[<AxesSubplot:title={'center':'salary'}>,
#         <AxesSubplot:title={'center':'sales'}>],
#        [<AxesSubplot:title={'center':'roe'}>,
#         <AxesSubplot:title={'center':'industry'}>]], dtype=object)

# %%
data_IQR.corr()
# Out:
#             salary     sales       roe  industry
# salary    1.000000  0.471278  0.299153 -0.223324
# sales     0.471278  1.000000 -0.076046 -0.106834
# roe       0.299153 -0.076046  1.000000 -0.050202
# industry -0.223324 -0.106834 -0.050202  1.000000
